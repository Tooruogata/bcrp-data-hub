# %%
import pandas as pd
import aiohttp
import os
from datetime import datetime
import asyncio
import duckdb

# %%
def control_panel():

    # Load metadata
    df_metadata = pd.read_csv(
        "https://estadisticas.bcrp.gob.pe/estadisticas/series/metadata",
        sep=";",
        encoding="latin1"
    )

    # Keep only necessary columns and rename them
    df_control = df_metadata[["Código de serie", "Nombre de serie"]].copy()
    df_control = df_control.rename(columns={
        "Código de serie": "codigo_serie",
        "Nombre de serie": "nombre_serie"
    })

    # Add control columns
    df_control["estado"] = "pendiente"
    df_control["ultima_actualizacion"] = ""
    df_control["observaciones"] = ""

    # Save control panel index
    df_control.to_csv("../data/metadata/control_series_index.csv", sep='|', index=False, encoding="utf-8")

    print(f"Saved control panel with {len(df_control)} series to metadata/control_series_index.csv")

# %%
async def fetch_series(session, codigo_serie, formato, inicio, fin, idioma, output_dir):
    url = f"https://estadisticas.bcrp.gob.pe/estadisticas/series/api/{codigo_serie}/{formato}/{inicio}/{fin}/{idioma}"

    try:
        async with session.get(url, timeout=30) as response:
            if response.status == 200:
                json_data = await response.json()
                periods = json_data.get("periods", [])

                if not periods:
                    return codigo_serie, "vacio", "", "Sin datos en API"

                df = pd.DataFrame(periods)

                os.makedirs(output_dir, exist_ok=True)
                output_path = os.path.join(output_dir, f"{codigo_serie}.parquet")
                df.to_parquet(output_path, index=False)

                return codigo_serie, "exito", datetime.utcnow().isoformat(), ""
            else:
                return codigo_serie, "fallo", "", f"HTTP {response.status}"

    except Exception as e:
        return codigo_serie, "fallo", "", str(e)

# %%
async def run_batch(df_control, formato, inicio, fin, idioma, output_dir, batch_size=100):
    import time
    from tqdm.notebook import tqdm

    # Keep only pendientes
    df_pending = df_control[df_control["estado"] == "pendiente"].copy()

    total = len(df_pending)
    print(f"Total series pendientes: {total}")
    
    updates = []

    async with aiohttp.ClientSession() as session:
        for i in range(0, total, batch_size):
            batch = df_pending.iloc[i:i+batch_size]
            print(f"\n🔄 Processing batch {i//batch_size + 1} ({i} to {i+len(batch)-1})")

            start = time.time()
            tasks = [
                fetch_series(session, row.codigo_serie, formato, inicio, fin, idioma, output_dir)
                for _, row in batch.iterrows()
            ]
            results = await asyncio.gather(*tasks)

            successes = 0
            failures = 0
            empties = 0

            for codigo, estado, timestamp, obs in results:
                updates.append((codigo, estado, timestamp, obs))

                if estado == "exito":
                    successes += 1
                    print(f"✅ {codigo} descargado.")
                elif estado == "vacio":
                    empties += 1
                    print(f"⚪ {codigo} sin datos.")
                else:
                    failures += 1
                    print(f"❌ {codigo} falló: {obs}")

            elapsed = round(time.time() - start, 2)
            print(f"⏱️ Batch done in {elapsed}s — ✅ {successes} | ⚪ {empties} | ❌ {failures}")

    # Apply updates
    for codigo, estado, timestamp, obs in updates:
        df_control.loc[df_control["codigo_serie"] == codigo, "estado"] = estado
        df_control.loc[df_control["codigo_serie"] == codigo, "ultima_actualizacion"] = timestamp
        df_control.loc[df_control["codigo_serie"] == codigo, "observaciones"] = obs

    df_control.to_csv("../data/metadata/control_series_index.csv", sep="|", index=False)
    print(f"\n✅ Control panel updated with {len(updates)} results.")

# %%
control_panel()
# Out:
# Saved control panel with 16418 series to metadata/control_series_index.csv

# %%
df_control = pd.read_csv("../data/metadata/control_series_index.csv", sep="|")

# %%
await run_batch(
    df_control=df_control,
    formato="json",
    inicio="2000-1",
    fin="2025-12",
    idioma="esp",
    output_dir="../data/bronze/",
    batch_size=100  # or tweak as needed
)
# Out:
# Total series pendientes: 16418
#
# 🔄 Processing batch 1 (0 to 99)
# /tmp/ipykernel_40799/3897400301.py:19: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return codigo_serie, "exito", datetime.utcnow().isoformat(), ""
# ✅ PN00001MM descargado.
# ✅ PN00002MM descargado.
# ✅ PN00003MM descargado.
# ✅ PN00004MM descargado.
# ✅ PN00005MM descargado.
# ✅ PN00006MM descargado.
# ✅ PN00007MM descargado.
# ✅ PN00008MM descargado.
# ✅ PN00009MM descargado.
# ✅ PN00010MM descargado.
# ✅ PN00011MM descargado.
# ✅ PN00012MM descargado.
# ✅ PN00013MM descargado.
# ✅ PN00014MM descargado.
# ✅ PN00015MM descargado.
# ✅ PN00016MM descargado.
# ✅ PN00021MM descargado.
# ✅ PN00023MM descargado.
# ✅ PN00025MM descargado.
# ✅ PN00026MM descargado.
# ✅ PN00030MM descargado.
# ✅ PN00031MM descargado.
# ✅ PN00032MM descargado.
# ✅ PN00033MM descargado.
# ✅ PN00034MM descargado.
# ✅ PN00039MM descargado.
# ✅ PN00040MM descargado.
# ✅ PN00041MM descargado.
# ✅ PN00042MM descargado.
# ✅ PN00043MM descargado.
# ✅ PN00044MM descargado.
# ✅ PN00045MM descargado.
# ✅ PN00046MM descargado.
# ✅ PN00050MM descargado.
# ✅ PN00051MM descargado.
# ✅ PN00052MM descargado.
# ✅ PN00053MM descargado.
# ✅ PN00054MM descargado.
# ✅ PN00058MM descargado.
# ✅ PN00059MM descargado.
# ✅ PN00060MM descargado.
# ✅ PN00061MM descargado.
# ✅ PN00063MM descargado.
# ✅ PN00065MM descargado.
# ✅ PN00066MM descargado.
# ✅ PN00067MM descargado.
# ✅ PN00068MM descargado.
# ✅ PN00069MM descargado.
# ✅ PN00074MM descargado.
# ✅ PN00075MM descargado.
# ✅ PN00077MM descargado.
# ✅ PN00079MM descargado.
# ✅ PN00080MM descargado.
# ✅ PN00081MM descargado.
# ✅ PN00082MM descargado.
# ✅ PN00083MM descargado.
# ✅ PN00084MM descargado.
# ✅ PN00085MM descargado.
# ✅ PN00086MM descargado.
# ✅ PN00087MM descargado.
# ✅ PN00088MM descargado.
# ✅ PN00089MM descargado.
# ✅ PN00090MM descargado.
# ✅ PN00091MM descargado.
# ✅ PN00092MM descargado.
# ✅ PN00093MM descargado.
# ✅ PN00094MM descargado.
# ✅ PN00095MM descargado.
# ✅ PN00100MM descargado.
# ✅ PN00102MM descargado.
# ✅ PN00104MM descargado.
# ✅ PN00105MM descargado.
# ✅ PN00109MM descargado.
# ✅ PN00110MM descargado.
# ✅ PN00111MM descargado.
# ✅ PN00112MM descargado.
# ✅ PN00113MM descargado.
# ✅ PN00114MM descargado.
# ✅ PN00115MM descargado.
# ✅ PN00116MM descargado.
# ✅ PN00117MM descargado.
# ✅ PN00118MM descargado.
# ✅ PN00119MM descargado.
# ✅ PN00120MM descargado.
# ✅ PN00121MM descargado.
# ✅ PN00123MM descargado.
# ✅ PN00124MM descargado.
# ✅ PN00128MM descargado.
# ✅ PN00129MM descargado.
# ✅ PN00130MM descargado.
# ✅ PN00131MM descargado.
# ✅ PN00132MM descargado.
# ✅ PN00133MM descargado.
# ✅ PN00134MM descargado.
# ✅ PN00135MM descargado.
# ✅ PN00136MM descargado.
# ✅ PN00137MM descargado.
# ✅ PN00138MM descargado.
# ✅ PN00139MM descargado.
# ✅ PN00140MM descargado.
# ⏱️ Batch done in 4.3s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 2 (100 to 199)
# ✅ PN00141MM descargado.
# ✅ PN00142MM descargado.
# ✅ PN00143MM descargado.
# ✅ PN00144MM descargado.
# ✅ PN00145MM descargado.
# ✅ PN00146MM descargado.
# ✅ PN00147MM descargado.
# ✅ PN00148MM descargado.
# ✅ PN00149MM descargado.
# ✅ PN00150MM descargado.
# ✅ PN00151MM descargado.
# ✅ PN00153MM descargado.
# ✅ PN00154MM descargado.
# ✅ PN00155MM descargado.
# ✅ PN00156MM descargado.
# ✅ PN00157MM descargado.
# ✅ PN00158MM descargado.
# ✅ PN00161MM descargado.
# ✅ PN00165MM descargado.
# ✅ PN00166MM descargado.
# ✅ PN00167MM descargado.
# ✅ PN00168MM descargado.
# ✅ PN00169MM descargado.
# ✅ PN00171MM descargado.
# ✅ PN00172MM descargado.
# ✅ PN00173MM descargado.
# ✅ PN00174MM descargado.
# ✅ PN00175MM descargado.
# ✅ PN00176MM descargado.
# ✅ PN00177MM descargado.
# ✅ PN00178MM descargado.
# ✅ PN00179MM descargado.
# ✅ PN00180MM descargado.
# ✅ PN00181MM descargado.
# ✅ PN00182MM descargado.
# ✅ PN00183MM descargado.
# ✅ PN00184MM descargado.
# ✅ PN00185MM descargado.
# ✅ PN00186MM descargado.
# ✅ PN00187MM descargado.
# ✅ PN00188MM descargado.
# ✅ PN00189MM descargado.
# ✅ PN00190MM descargado.
# ✅ PN00191MM descargado.
# ✅ PN00192MM descargado.
# ✅ PN00193MM descargado.
# ✅ PN00194MM descargado.
# ✅ PN00195MM descargado.
# ✅ PN00196MM descargado.
# ✅ PN00197MM descargado.
# ✅ PN00198MM descargado.
# ✅ PN00199MM descargado.
# ✅ PN00200MM descargado.
# ✅ PN00201MM descargado.
# ✅ PN00202MM descargado.
# ✅ PN00203MM descargado.
# ✅ PN00204MM descargado.
# ✅ PN00205MM descargado.
# ✅ PN00206MM descargado.
# ✅ PN00207MM descargado.
# ✅ PN00208MM descargado.
# ✅ PN00209MM descargado.
# ✅ PN00210MM descargado.
# ✅ PN00211MM descargado.
# ✅ PN00212MM descargado.
# ✅ PN00213MM descargado.
# ✅ PN00214MM descargado.
# ✅ PN00215MM descargado.
# ✅ PN00216MM descargado.
# ✅ PN00217MM descargado.
# ✅ PN00218MM descargado.
# ✅ PN00219MM descargado.
# ✅ PN00220MM descargado.
# ✅ PN00221MM descargado.
# ✅ PN00222MM descargado.
# ✅ PN00223MM descargado.
# ✅ PN00224MM descargado.
# ✅ PN00225MM descargado.
# ✅ PN00226MM descargado.
# ✅ PN00227MM descargado.
# ✅ PN00228MM descargado.
# ✅ PN00229MM descargado.
# ✅ PN00230MM descargado.
# ✅ PN00231MM descargado.
# ✅ PN00232MM descargado.
# ✅ PN00233MM descargado.
# ✅ PN00234MM descargado.
# ✅ PN00235MM descargado.
# ✅ PN00236MM descargado.
# ✅ PN00237MM descargado.
# ✅ PN00238MM descargado.
# ✅ PN00239MM descargado.
# ✅ PN00240MM descargado.
# ✅ PN00241MM descargado.
# ✅ PN00242MM descargado.
# ✅ PN00243MM descargado.
# ✅ PN00244MM descargado.
# ✅ PN00245MM descargado.
# ✅ PN00246MM descargado.
# ✅ PN00247MM descargado.
# ⏱️ Batch done in 2.03s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 3 (200 to 299)
# ✅ PN00248MM descargado.
# ✅ PN00249MM descargado.
# ✅ PN00250MM descargado.
# ✅ PN00251MM descargado.
# ✅ PN00252MM descargado.
# ✅ PN00253MM descargado.
# ✅ PN00254MM descargado.
# ✅ PN00255MM descargado.
# ✅ PN00256MM descargado.
# ✅ PN00257MM descargado.
# ✅ PN00258MM descargado.
# ✅ PN00259MM descargado.
# ✅ PN00260MM descargado.
# ✅ PN00261MM descargado.
# ✅ PN00262MM descargado.
# ✅ PN00263MM descargado.
# ✅ PN00264MM descargado.
# ✅ PN00265MM descargado.
# ✅ PN00266MM descargado.
# ✅ PN00267MM descargado.
# ✅ PN00268MM descargado.
# ✅ PN00269MM descargado.
# ✅ PN00270MM descargado.
# ✅ PN00271MM descargado.
# ✅ PN00272MM descargado.
# ✅ PN00273MM descargado.
# ✅ PN00274MM descargado.
# ✅ PN00275MM descargado.
# ✅ PN00276MM descargado.
# ✅ PN00277MM descargado.
# ✅ PN00278MM descargado.
# ✅ PN00279MM descargado.
# ✅ PN00280MM descargado.
# ✅ PN00281MM descargado.
# ✅ PN00282MM descargado.
# ✅ PN00283MM descargado.
# ✅ PN00284MM descargado.
# ✅ PN00285MM descargado.
# ✅ PN00286MM descargado.
# ✅ PN00287MM descargado.
# ✅ PN00288MM descargado.
# ✅ PN00289MM descargado.
# ✅ PN00290MM descargado.
# ✅ PN00291MM descargado.
# ✅ PN00292MM descargado.
# ✅ PN00293MM descargado.
# ✅ PN00294MM descargado.
# ✅ PN00295MM descargado.
# ✅ PN00296MM descargado.
# ✅ PN00297MM descargado.
# ✅ PN00298MM descargado.
# ✅ PN00299MM descargado.
# ✅ PN00300MM descargado.
# ✅ PN00301MM descargado.
# ✅ PN00302MM descargado.
# ✅ PN00303MM descargado.
# ✅ PN00304MM descargado.
# ✅ PN00305MM descargado.
# ✅ PN00306MM descargado.
# ✅ PN00307MM descargado.
# ✅ PN00308MM descargado.
# ✅ PN00309MM descargado.
# ✅ PN00310MM descargado.
# ✅ PN00311MM descargado.
# ✅ PN00312MM descargado.
# ✅ PN00313MM descargado.
# ✅ PN00314MM descargado.
# ✅ PN00315MM descargado.
# ✅ PN00316MM descargado.
# ✅ PN00317MM descargado.
# ✅ PN00318MM descargado.
# ✅ PN00319MM descargado.
# ✅ PN00320MM descargado.
# ✅ PN00321MM descargado.
# ✅ PN00322MM descargado.
# ✅ PN00323MM descargado.
# ✅ PN00324MM descargado.
# ✅ PN00325MM descargado.
# ✅ PN00326MM descargado.
# ✅ PN00327MM descargado.
# ✅ PN00328MM descargado.
# ✅ PN00329MM descargado.
# ✅ PN00330MM descargado.
# ✅ PN00331MM descargado.
# ✅ PN00332MM descargado.
# ✅ PN00333MM descargado.
# ✅ PN00334MM descargado.
# ✅ PN00335MM descargado.
# ✅ PN00336MM descargado.
# ✅ PN00337MM descargado.
# ✅ PN00338MM descargado.
# ✅ PN00339MM descargado.
# ✅ PN00340MM descargado.
# ✅ PN00341MM descargado.
# ✅ PN00342MM descargado.
# ✅ PN00343MM descargado.
# ✅ PN00344MM descargado.
# ✅ PN00345MM descargado.
# ✅ PN00346MM descargado.
# ✅ PN00347MM descargado.
# ⏱️ Batch done in 2.75s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 4 (300 to 399)
# ✅ PN00348MM descargado.
# ✅ PN00349MM descargado.
# ✅ PN00350MM descargado.
# ✅ PN00351MM descargado.
# ✅ PN00352MM descargado.
# ✅ PN00353MM descargado.
# ✅ PN00354MM descargado.
# ✅ PN00355MM descargado.
# ✅ PN00356MM descargado.
# ✅ PN00357MM descargado.
# ✅ PN00358MM descargado.
# ✅ PN00359MM descargado.
# ✅ PN00360MM descargado.
# ✅ PN00361MM descargado.
# ✅ PN00362MM descargado.
# ✅ PN00363MM descargado.
# ✅ PN00364MM descargado.
# ✅ PN00365MM descargado.
# ✅ PN00366MM descargado.
# ✅ PN00367MM descargado.
# ✅ PN00368MM descargado.
# ✅ PN00369MM descargado.
# ✅ PN00370MM descargado.
# ✅ PN00371MM descargado.
# ✅ PN00372MM descargado.
# ✅ PN00373MM descargado.
# ✅ PN00374MM descargado.
# ✅ PN00375MM descargado.
# ✅ PN00376MM descargado.
# ✅ PN00377MM descargado.
# ✅ PN00378MM descargado.
# ✅ PN00379MM descargado.
# ✅ PN00380MM descargado.
# ✅ PN00381MM descargado.
# ✅ PN00382MM descargado.
# ✅ PN00383MM descargado.
# ✅ PN00384MM descargado.
# ✅ PN00385MM descargado.
# ✅ PN00386MM descargado.
# ✅ PN00387MM descargado.
# ✅ PN00388MM descargado.
# ✅ PN00389MM descargado.
# ✅ PN00390MM descargado.
# ✅ PN00391MM descargado.
# ✅ PN00392MM descargado.
# ✅ PN00393MM descargado.
# ✅ PN00394MM descargado.
# ✅ PN00395MM descargado.
# ✅ PN00396MM descargado.
# ✅ PN00397MM descargado.
# ✅ PN00398MM descargado.
# ✅ PN00399MM descargado.
# ✅ PN00400MM descargado.
# ✅ PN00401MM descargado.
# ✅ PN00402MM descargado.
# ✅ PN00403MM descargado.
# ✅ PN00404MM descargado.
# ✅ PN00405MM descargado.
# ✅ PN00406MM descargado.
# ✅ PN00407MM descargado.
# ✅ PN00408MM descargado.
# ✅ PN00409MM descargado.
# ✅ PN00410MM descargado.
# ✅ PN00411MM descargado.
# ✅ PN00412MM descargado.
# ✅ PN00413MM descargado.
# ✅ PN00414MM descargado.
# ✅ PN00415MM descargado.
# ✅ PN00416MM descargado.
# ✅ PN00417MM descargado.
# ✅ PN00418MM descargado.
# ✅ PN00419MM descargado.
# ✅ PN00420MM descargado.
# ✅ PN00421MM descargado.
# ✅ PN00422MM descargado.
# ✅ PN00423MM descargado.
# ✅ PN00424MM descargado.
# ✅ PN00425MM descargado.
# ✅ PN00426MM descargado.
# ✅ PN00427MM descargado.
# ✅ PN00428MM descargado.
# ✅ PN00429MM descargado.
# ✅ PN00430MM descargado.
# ✅ PN00431MM descargado.
# ✅ PN00432MM descargado.
# ✅ PN00433MM descargado.
# ✅ PN00434MM descargado.
# ✅ PN00435MM descargado.
# ✅ PN00436MM descargado.
# ✅ PN00437MM descargado.
# ✅ PN00438MM descargado.
# ✅ PN00439MM descargado.
# ✅ PN00440MM descargado.
# ✅ PN00441MM descargado.
# ✅ PN00442MM descargado.
# ✅ PN00443MM descargado.
# ✅ PN00444MM descargado.
# ✅ PN00445MM descargado.
# ✅ PN00446MM descargado.
# ✅ PN00447MM descargado.
# ⏱️ Batch done in 1.96s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 5 (400 to 499)
# ✅ PN00448MM descargado.
# ✅ PN00449MM descargado.
# ✅ PN00450MM descargado.
# ✅ PN00451MM descargado.
# ✅ PN00452MM descargado.
# ✅ PN00453MM descargado.
# ✅ PN00454MM descargado.
# ✅ PN00455MM descargado.
# ✅ PN00456MM descargado.
# ✅ PN00457MM descargado.
# ✅ PN00458MM descargado.
# ✅ PN00459MM descargado.
# ✅ PN00460MM descargado.
# ✅ PN00461MM descargado.
# ✅ PN00462MM descargado.
# ✅ PN00463MM descargado.
# ✅ PN00464MM descargado.
# ✅ PN00465MM descargado.
# ✅ PN00466MM descargado.
# ✅ PN00467MM descargado.
# ✅ PN00468MM descargado.
# ✅ PN00469MM descargado.
# ✅ PN00470MM descargado.
# ✅ PN00471MM descargado.
# ✅ PN00472MM descargado.
# ✅ PN00473MM descargado.
# ✅ PN00474MM descargado.
# ✅ PN00475MM descargado.
# ✅ PN00476MM descargado.
# ✅ PN00477MM descargado.
# ✅ PN00478MM descargado.
# ✅ PN00479MM descargado.
# ✅ PN00480MM descargado.
# ✅ PN00481MM descargado.
# ✅ PN00482MM descargado.
# ✅ PN00483MM descargado.
# ✅ PN00484MM descargado.
# ✅ PN00485MM descargado.
# ✅ PN00486MM descargado.
# ✅ PN00487MM descargado.
# ✅ PN00488MM descargado.
# ✅ PN00489MM descargado.
# ✅ PN00490MM descargado.
# ✅ PN00491MM descargado.
# ✅ PN00492MM descargado.
# ✅ PN00493MM descargado.
# ✅ PN00494MM descargado.
# ✅ PN00495MM descargado.
# ✅ PN00496MM descargado.
# ✅ PN00497MM descargado.
# ✅ PN00498MM descargado.
# ✅ PN00499MM descargado.
# ✅ PN00500MM descargado.
# ✅ PN00501MM descargado.
# ✅ PN00502MM descargado.
# ✅ PN00503MM descargado.
# ✅ PN00504MM descargado.
# ✅ PN00505MM descargado.
# ✅ PN00506MM descargado.
# ✅ PN00507MM descargado.
# ✅ PN00508MM descargado.
# ✅ PN00509MM descargado.
# ✅ PN00510MM descargado.
# ✅ PN00511MM descargado.
# ✅ PN00512MM descargado.
# ✅ PN00513MM descargado.
# ✅ PN00514MM descargado.
# ✅ PN00515MM descargado.
# ✅ PN00516MM descargado.
# ✅ PN00517MM descargado.
# ✅ PN00518MM descargado.
# ✅ PN00519MM descargado.
# ✅ PN00520MM descargado.
# ✅ PN00521MM descargado.
# ✅ PN00522MM descargado.
# ✅ PN00523MM descargado.
# ✅ PN00524MM descargado.
# ✅ PN00525MM descargado.
# ✅ PN00526MM descargado.
# ✅ PN00527MM descargado.
# ✅ PN00528MM descargado.
# ✅ PN00529MM descargado.
# ✅ PN00530MM descargado.
# ✅ PN00531MM descargado.
# ✅ PN00532MM descargado.
# ✅ PN00533MM descargado.
# ✅ PN00534MM descargado.
# ✅ PN00535MM descargado.
# ✅ PN00536MM descargado.
# ✅ PN00537MM descargado.
# ✅ PN00538MM descargado.
# ✅ PN00539MM descargado.
# ✅ PN00540MM descargado.
# ✅ PN00541MM descargado.
# ✅ PN00542MM descargado.
# ✅ PN00543MM descargado.
# ✅ PN00544MM descargado.
# ✅ PN00545MM descargado.
# ✅ PN00546MM descargado.
# ✅ PN00547MM descargado.
# ⏱️ Batch done in 2.05s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 6 (500 to 599)
# ✅ PN00548MM descargado.
# ✅ PN00549MM descargado.
# ✅ PN00550MM descargado.
# ✅ PN00551MM descargado.
# ✅ PN00552MM descargado.
# ✅ PN00553MM descargado.
# ✅ PN00554MM descargado.
# ✅ PN00555MM descargado.
# ✅ PN00556MM descargado.
# ✅ PN00557MM descargado.
# ✅ PN00558MM descargado.
# ✅ PN00559MM descargado.
# ✅ PN00560MM descargado.
# ✅ PN00561MM descargado.
# ✅ PN00562MM descargado.
# ✅ PN00563MM descargado.
# ✅ PN00564MM descargado.
# ✅ PN00565MM descargado.
# ✅ PN00566MM descargado.
# ✅ PN00567MM descargado.
# ✅ PN00568MM descargado.
# ✅ PN00569MM descargado.
# ✅ PN00573MM descargado.
# ✅ PN00574MM descargado.
# ✅ PN00575MM descargado.
# ✅ PN00576MM descargado.
# ✅ PN00577MM descargado.
# ✅ PN00578MM descargado.
# ✅ PN00580MM descargado.
# ✅ PN00581MM descargado.
# ✅ PN00582MM descargado.
# ✅ PN00584MM descargado.
# ✅ PN00585MM descargado.
# ✅ PN00586MM descargado.
# ✅ PN00587MM descargado.
# ✅ PN00588MM descargado.
# ✅ PN00589MM descargado.
# ✅ PN00593MM descargado.
# ✅ PN00594MM descargado.
# ✅ PN00595MM descargado.
# ✅ PN00596MM descargado.
# ✅ PN00597MM descargado.
# ✅ PN00598MM descargado.
# ✅ PN00599MM descargado.
# ✅ PN00600MM descargado.
# ✅ PN00601MM descargado.
# ✅ PN00602MM descargado.
# ✅ PN00603MM descargado.
# ✅ PN00604MM descargado.
# ✅ PN00605MM descargado.
# ✅ PN00606MM descargado.
# ✅ PN00607MM descargado.
# ✅ PN00608MM descargado.
# ✅ PN00609MM descargado.
# ✅ PN00610MM descargado.
# ✅ PN00611MM descargado.
# ✅ PN00612MM descargado.
# ✅ PN00613MM descargado.
# ✅ PN00614MM descargado.
# ✅ PN00615MM descargado.
# ✅ PN00616MM descargado.
# ✅ PN00617MM descargado.
# ✅ PN00618MM descargado.
# ✅ PN00619MM descargado.
# ✅ PN00620MM descargado.
# ✅ PN00621MM descargado.
# ✅ PN00622MM descargado.
# ✅ PN00623MM descargado.
# ✅ PN00624MM descargado.
# ✅ PN00625MM descargado.
# ✅ PN00626MM descargado.
# ✅ PN00627MM descargado.
# ✅ PN00628MM descargado.
# ✅ PN00629MM descargado.
# ✅ PN00630MM descargado.
# ✅ PN00631MM descargado.
# ✅ PN00632MM descargado.
# ✅ PN00633MM descargado.
# ✅ PN00634MM descargado.
# ✅ PN00635MM descargado.
# ✅ PN00636MM descargado.
# ✅ PN00637MM descargado.
# ✅ PN00638MM descargado.
# ✅ PN00639MM descargado.
# ✅ PN00640MM descargado.
# ✅ PN00641MM descargado.
# ✅ PN00642MM descargado.
# ✅ PN00643MM descargado.
# ✅ PN00644MM descargado.
# ✅ PN00645MM descargado.
# ✅ PN00646MM descargado.
# ✅ PN00647MM descargado.
# ✅ PN00648MM descargado.
# ✅ PN00649MM descargado.
# ✅ PN00650MM descargado.
# ✅ PN00651MM descargado.
# ✅ PN00652MM descargado.
# ✅ PN00653MM descargado.
# ✅ PN00654MM descargado.
# ✅ PN00655MM descargado.
# ⏱️ Batch done in 1.88s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 7 (600 to 699)
# ✅ PN00656MM descargado.
# ✅ PN00657MM descargado.
# ✅ PN00658MM descargado.
# ✅ PN00659MM descargado.
# ✅ PN00660MM descargado.
# ✅ PN00661MM descargado.
# ✅ PN00662MM descargado.
# ✅ PN00663MM descargado.
# ✅ PN00664MM descargado.
# ✅ PN00665MM descargado.
# ✅ PN00666MM descargado.
# ✅ PN00667MM descargado.
# ✅ PN00668MM descargado.
# ✅ PN00669MM descargado.
# ✅ PN00670MM descargado.
# ✅ PN00671MM descargado.
# ✅ PN00672MM descargado.
# ✅ PN00673MM descargado.
# ✅ PN00674MM descargado.
# ✅ PN00675MM descargado.
# ✅ PN00676MM descargado.
# ✅ PN00677MM descargado.
# ✅ PN00678MM descargado.
# ✅ PN00679MM descargado.
# ✅ PN00680MM descargado.
# ✅ PN00681MM descargado.
# ✅ PN00682MM descargado.
# ✅ PN00683MM descargado.
# ✅ PN00684MM descargado.
# ✅ PN00685MM descargado.
# ✅ PN00686MM descargado.
# ✅ PN00687MM descargado.
# ✅ PN00688MM descargado.
# ✅ PN00689MM descargado.
# ✅ PN00690MM descargado.
# ✅ PN00691MM descargado.
# ✅ PN00692MM descargado.
# ✅ PN00693MM descargado.
# ✅ PN00694MM descargado.
# ✅ PN00695MM descargado.
# ✅ PN00696MM descargado.
# ✅ PN00697MM descargado.
# ✅ PN00698MM descargado.
# ✅ PN00699MM descargado.
# ✅ PN00700MM descargado.
# ✅ PN00701MM descargado.
# ✅ PN00702MM descargado.
# ✅ PN00703MM descargado.
# ✅ PN00704MM descargado.
# ✅ PN00705MM descargado.
# ✅ PN00706MM descargado.
# ✅ PN00707MM descargado.
# ✅ PN00708MM descargado.
# ✅ PN00709MM descargado.
# ✅ PN00710MM descargado.
# ✅ PN00711MM descargado.
# ✅ PN00712MM descargado.
# ✅ PN00713MM descargado.
# ✅ PN00714MM descargado.
# ✅ PN00715MM descargado.
# ✅ PN00716MM descargado.
# ✅ PN00717MM descargado.
# ✅ PN00718MM descargado.
# ✅ PN00719MM descargado.
# ✅ PN00720MM descargado.
# ✅ PN00721MM descargado.
# ✅ PN00722MM descargado.
# ✅ PN00723MM descargado.
# ✅ PN00724MM descargado.
# ✅ PN00725MM descargado.
# ✅ PN00726MM descargado.
# ✅ PN00727MM descargado.
# ✅ PN00728MM descargado.
# ✅ PN00729MM descargado.
# ✅ PN00730MM descargado.
# ✅ PN00731MM descargado.
# ✅ PN00732MM descargado.
# ✅ PN00733MM descargado.
# ✅ PN00734MM descargado.
# ✅ PN00735MM descargado.
# ✅ PN00736MM descargado.
# ✅ PN00737MM descargado.
# ✅ PN00738MM descargado.
# ✅ PN00739MM descargado.
# ✅ PN00740MM descargado.
# ✅ PN00741MM descargado.
# ✅ PN00742MM descargado.
# ✅ PN00743MM descargado.
# ✅ PN00744MM descargado.
# ✅ PN00745MM descargado.
# ✅ PN00746MM descargado.
# ✅ PN00747MM descargado.
# ✅ PN00748MM descargado.
# ✅ PN00749MM descargado.
# ✅ PN00750MM descargado.
# ✅ PN00751MM descargado.
# ✅ PN00752MM descargado.
# ✅ PN00753MM descargado.
# ✅ PN00754MM descargado.
# ✅ PN00755MM descargado.
# ⏱️ Batch done in 1.78s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 8 (700 to 799)
# ✅ PN00756MM descargado.
# ✅ PN00757MM descargado.
# ✅ PN00758MM descargado.
# ✅ PN00759MM descargado.
# ✅ PN00760MM descargado.
# ✅ PN00761MM descargado.
# ✅ PN00762MM descargado.
# ✅ PN00763MM descargado.
# ✅ PN00764MM descargado.
# ✅ PN00765MM descargado.
# ✅ PN00766MM descargado.
# ✅ PN00767MM descargado.
# ✅ PN00768MM descargado.
# ✅ PN00769MM descargado.
# ✅ PN00770MM descargado.
# ✅ PN00771MM descargado.
# ✅ PN00772MM descargado.
# ✅ PN00773MM descargado.
# ✅ PN00774MM descargado.
# ✅ PN00775MM descargado.
# ✅ PN00776MM descargado.
# ✅ PN00777MM descargado.
# ✅ PN00778MM descargado.
# ✅ PN00779MM descargado.
# ✅ PN00780MM descargado.
# ✅ PN00781MM descargado.
# ✅ PN00782MM descargado.
# ✅ PN00783MM descargado.
# ✅ PN00784MM descargado.
# ✅ PN00785MM descargado.
# ✅ PN00786MM descargado.
# ✅ PN00787MM descargado.
# ✅ PN00788MM descargado.
# ✅ PN00789MM descargado.
# ✅ PN00790MM descargado.
# ✅ PN00791MM descargado.
# ✅ PN00792MM descargado.
# ✅ PN00793MM descargado.
# ✅ PN00794MM descargado.
# ✅ PN00795MM descargado.
# ✅ PN00796MM descargado.
# ✅ PN00797MM descargado.
# ✅ PN00798MM descargado.
# ✅ PN00799MM descargado.
# ✅ PN00800MM descargado.
# ✅ PN00801MM descargado.
# ✅ PN00802MM descargado.
# ✅ PN00803MM descargado.
# ✅ PN00804MM descargado.
# ✅ PN00805MM descargado.
# ✅ PN00806MM descargado.
# ✅ PN00807MM descargado.
# ✅ PN00808MM descargado.
# ✅ PN00809MM descargado.
# ✅ PN00810MM descargado.
# ✅ PN00811MM descargado.
# ✅ PN00812MM descargado.
# ✅ PN00813MM descargado.
# ✅ PN00814MM descargado.
# ✅ PN00815MM descargado.
# ✅ PN00816MM descargado.
# ✅ PN00817MM descargado.
# ✅ PN00818MM descargado.
# ✅ PN00819MM descargado.
# ✅ PN00820MM descargado.
# ✅ PN00821MM descargado.
# ✅ PN00822MM descargado.
# ✅ PN00823MM descargado.
# ✅ PN00824MM descargado.
# ✅ PN00825MM descargado.
# ✅ PN00826MM descargado.
# ✅ PN00827MM descargado.
# ✅ PN00828MM descargado.
# ✅ PN00829MM descargado.
# ✅ PN00830MM descargado.
# ✅ PN00831MM descargado.
# ✅ PN00832MM descargado.
# ✅ PN00833MM descargado.
# ✅ PN00834MM descargado.
# ✅ PN00835MM descargado.
# ✅ PN00836MM descargado.
# ✅ PN00837MM descargado.
# ✅ PN00838MM descargado.
# ✅ PN00839MM descargado.
# ✅ PN00840MM descargado.
# ✅ PN00841MM descargado.
# ✅ PN00842MM descargado.
# ✅ PN00843MM descargado.
# ✅ PN00844MM descargado.
# ✅ PN00845MM descargado.
# ✅ PN00846MM descargado.
# ✅ PN00847MM descargado.
# ✅ PN00848MM descargado.
# ✅ PN00849MM descargado.
# ✅ PN00850MM descargado.
# ✅ PN00851MM descargado.
# ✅ PN00852MM descargado.
# ✅ PN00853MM descargado.
# ✅ PN00854MM descargado.
# ✅ PN00855MM descargado.
# ⏱️ Batch done in 1.89s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 9 (800 to 899)
# ✅ PN00856MM descargado.
# ✅ PN00857MM descargado.
# ✅ PN00858MM descargado.
# ✅ PN00859MM descargado.
# ✅ PN00860MM descargado.
# ✅ PN00861MM descargado.
# ✅ PN00862MM descargado.
# ✅ PN00863MM descargado.
# ✅ PN00864MM descargado.
# ✅ PN00865MM descargado.
# ✅ PN00866MM descargado.
# ✅ PN00867MM descargado.
# ✅ PN00868MM descargado.
# ✅ PN00869MM descargado.
# ✅ PN00870MM descargado.
# ✅ PN00871MM descargado.
# ✅ PN00872MM descargado.
# ✅ PN00873MM descargado.
# ✅ PN00874MM descargado.
# ✅ PN00875MM descargado.
# ✅ PN00876MM descargado.
# ✅ PN00877MM descargado.
# ✅ PN00878MM descargado.
# ✅ PN00879MM descargado.
# ✅ PN00880MM descargado.
# ✅ PN00881MM descargado.
# ✅ PN00882MM descargado.
# ✅ PN00883MM descargado.
# ✅ PN00884MM descargado.
# ✅ PN00885MM descargado.
# ✅ PN00886MM descargado.
# ✅ PN00887MM descargado.
# ✅ PN00888MM descargado.
# ✅ PN00889MM descargado.
# ✅ PN00890MM descargado.
# ✅ PN00891MM descargado.
# ✅ PN00892MM descargado.
# ✅ PN00893MM descargado.
# ✅ PN00894MM descargado.
# ✅ PN00895MM descargado.
# ✅ PN00896MM descargado.
# ✅ PN00897MM descargado.
# ✅ PN00898MM descargado.
# ✅ PN00899MM descargado.
# ✅ PN00900MM descargado.
# ✅ PN00901MM descargado.
# ✅ PN00902MM descargado.
# ✅ PN00903MM descargado.
# ✅ PN00904MM descargado.
# ✅ PN00905MM descargado.
# ✅ PN00906MM descargado.
# ✅ PN00907MM descargado.
# ✅ PN00908MM descargado.
# ✅ PN00909MM descargado.
# ✅ PN00910MM descargado.
# ✅ PN00911MM descargado.
# ✅ PN00912MM descargado.
# ✅ PN00913MM descargado.
# ✅ PN00914MM descargado.
# ✅ PN00915MM descargado.
# ✅ PN00916MM descargado.
# ✅ PN00917MM descargado.
# ✅ PN00918MM descargado.
# ✅ PN00919MM descargado.
# ✅ PN00920MM descargado.
# ✅ PN00921MM descargado.
# ✅ PN00922MM descargado.
# ✅ PN00923MM descargado.
# ✅ PN00924MM descargado.
# ✅ PN00925MM descargado.
# ✅ PN00926MM descargado.
# ✅ PN00927MM descargado.
# ✅ PN00928MM descargado.
# ✅ PN00929MM descargado.
# ✅ PN00930MM descargado.
# ✅ PN00931MM descargado.
# ✅ PN00932MM descargado.
# ✅ PN00933MM descargado.
# ✅ PN00934MM descargado.
# ✅ PN00935MM descargado.
# ✅ PN00936MM descargado.
# ✅ PN00937MM descargado.
# ✅ PN00938MM descargado.
# ✅ PN00939MM descargado.
# ✅ PN00940MM descargado.
# ✅ PN00941MM descargado.
# ✅ PN00942MM descargado.
# ✅ PN00943MM descargado.
# ✅ PN00944MM descargado.
# ✅ PN00945MM descargado.
# ✅ PN00946MM descargado.
# ✅ PN00947MM descargado.
# ✅ PN00948MM descargado.
# ✅ PN00949MM descargado.
# ✅ PN00950MM descargado.
# ✅ PN00951MM descargado.
# ✅ PN00952MM descargado.
# ✅ PN00953MM descargado.
# ✅ PN00954MM descargado.
# ✅ PN00955MM descargado.
# ⏱️ Batch done in 1.88s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 10 (900 to 999)
# ✅ PN00956MM descargado.
# ✅ PN00957MM descargado.
# ✅ PN00958MM descargado.
# ✅ PN00959MM descargado.
# ✅ PN00960MM descargado.
# ✅ PN00961MM descargado.
# ✅ PN00962MM descargado.
# ✅ PN00963MM descargado.
# ✅ PN00964MM descargado.
# ✅ PN00965MM descargado.
# ✅ PN00966MM descargado.
# ✅ PN00967MM descargado.
# ✅ PN00968MM descargado.
# ✅ PN00969MM descargado.
# ✅ PN00970MM descargado.
# ✅ PN00971MM descargado.
# ✅ PN00972MM descargado.
# ✅ PN00973MM descargado.
# ✅ PN00974MM descargado.
# ✅ PN00975MM descargado.
# ✅ PN00976MM descargado.
# ✅ PN00977MM descargado.
# ✅ PN00978MM descargado.
# ✅ PN00979MM descargado.
# ✅ PN00980MM descargado.
# ✅ PN00981MM descargado.
# ✅ PN00982MM descargado.
# ✅ PN00983MM descargado.
# ✅ PN00984MM descargado.
# ✅ PN00985MM descargado.
# ✅ PN00986MM descargado.
# ✅ PN00987MM descargado.
# ✅ PN00988MM descargado.
# ✅ PN00989MM descargado.
# ✅ PN00990MM descargado.
# ✅ PN00991MM descargado.
# ✅ PN00992MM descargado.
# ✅ PN00993MM descargado.
# ✅ PN00994MM descargado.
# ✅ PN00995MM descargado.
# ❌ PN00996MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN00996MM/json/2000-1/2025-12/esp'
# ❌ PN00997MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN00997MM/json/2000-1/2025-12/esp'
# ✅ PN00998MM descargado.
# ✅ PN00999MM descargado.
# ✅ PN01000MM descargado.
# ❌ PN01001MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01001MM/json/2000-1/2025-12/esp'
# ❌ PN01002MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01002MM/json/2000-1/2025-12/esp'
# ✅ PN01003MM descargado.
# ❌ PN01004MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01004MM/json/2000-1/2025-12/esp'
# ✅ PN01005MM descargado.
# ✅ PN01006MM descargado.
# ✅ PN01007MM descargado.
# ✅ PN01008MM descargado.
# ✅ PN01009MM descargado.
# ✅ PN01010MM descargado.
# ✅ PN01011MM descargado.
# ✅ PN01012MM descargado.
# ✅ PN01014MM descargado.
# ✅ PN01015MM descargado.
# ✅ PN01016MM descargado.
# ✅ PN01017MM descargado.
# ✅ PN01018MM descargado.
# ✅ PN01019MM descargado.
# ✅ PN01020MM descargado.
# ✅ PN01021MM descargado.
# ✅ PN01022MM descargado.
# ✅ PN01023MM descargado.
# ✅ PN01024MM descargado.
# ✅ PN01025MM descargado.
# ✅ PN01026MM descargado.
# ✅ PN01027MM descargado.
# ✅ PN01028MM descargado.
# ✅ PN01029MM descargado.
# ✅ PN01030MM descargado.
# ✅ PN01031MM descargado.
# ✅ PN01032MM descargado.
# ✅ PN01033MM descargado.
# ✅ PN01034MM descargado.
# ✅ PN01035MM descargado.
# ✅ PN01036MM descargado.
# ❌ PN01037MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01037MM/json/2000-1/2025-12/esp'
# ❌ PN01038MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01038MM/json/2000-1/2025-12/esp'
# ✅ PN01039MM descargado.
# ✅ PN01040MM descargado.
# ✅ PN01041MM descargado.
# ✅ PN01042MM descargado.
# ✅ PN01043MM descargado.
# ✅ PN01044MM descargado.
# ✅ PN01045MM descargado.
# ✅ PN01046MM descargado.
# ❌ PN01047MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01047MM/json/2000-1/2025-12/esp'
# ❌ PN01048MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01048MM/json/2000-1/2025-12/esp'
# ❌ PN01049MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01049MM/json/2000-1/2025-12/esp'
# ❌ PN01050MM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01050MM/json/2000-1/2025-12/esp'
# ✅ PN01052MM descargado.
# ✅ PN01053MM descargado.
# ✅ PN01054MM descargado.
# ✅ PN01055MM descargado.
# ✅ PN01056MM descargado.
# ✅ PN01057MM descargado.
# ⏱️ Batch done in 1.71s — ✅ 89 | ⚪ 0 | ❌ 11
#
# 🔄 Processing batch 11 (1000 to 1099)
# ✅ PN01058MM descargado.
# ✅ PN01059MM descargado.
# ✅ PN01060MM descargado.
# ✅ PN01061MM descargado.
# ✅ PN01062MM descargado.
# ✅ PN01063MM descargado.
# ✅ PN01064MM descargado.
# ✅ PN01065MM descargado.
# ✅ PN01066MM descargado.
# ✅ PN01067MM descargado.
# ✅ PN01068MM descargado.
# ✅ PN01069MM descargado.
# ✅ PN01070MM descargado.
# ✅ PN01071MM descargado.
# ✅ PN01072MM descargado.
# ✅ PN01073MM descargado.
# ✅ PN01074MM descargado.
# ✅ PN01075MM descargado.
# ✅ PN01076MM descargado.
# ✅ PN01077MM descargado.
# ✅ PN01078MM descargado.
# ✅ PN01079MM descargado.
# ✅ PN01080MM descargado.
# ✅ PN01081MM descargado.
# ✅ PN01082MM descargado.
# ✅ PN01083MM descargado.
# ✅ PN01084MM descargado.
# ✅ PN01085MM descargado.
# ✅ PN01103MM descargado.
# ✅ PN01104MM descargado.
# ✅ PN01105MM descargado.
# ✅ PN01106MM descargado.
# ✅ PN01107MM descargado.
# ✅ PN01108MM descargado.
# ✅ PN01109MM descargado.
# ✅ PN01110MM descargado.
# ✅ PN01111MM descargado.
# ✅ PN01112MM descargado.
# ✅ PN01113MM descargado.
# ✅ PN01114MM descargado.
# ✅ PN01115MM descargado.
# ✅ PN01116MM descargado.
# ✅ PN01117MM descargado.
# ✅ PN01118MM descargado.
# ✅ PN01119MM descargado.
# ✅ PN01120MM descargado.
# ✅ PN01121MM descargado.
# ✅ PN01122MM descargado.
# ✅ PN01123MM descargado.
# ✅ PN01124MM descargado.
# ✅ PN01125MM descargado.
# ✅ PN01126MM descargado.
# ✅ PN01127MM descargado.
# ✅ PN01128MM descargado.
# ✅ PN01129XM descargado.
# ✅ PN01130XM descargado.
# ✅ PN01131XM descargado.
# ✅ PN01132XM descargado.
# ✅ PN01133XM descargado.
# ✅ PN01134XM descargado.
# ✅ PN01135XM descargado.
# ✅ PN01136XM descargado.
# ✅ PN01137XM descargado.
# ✅ PN01138XM descargado.
# ✅ PN01142MM descargado.
# ✅ PN01143MM descargado.
# ✅ PN01144MM descargado.
# ✅ PN01145MM descargado.
# ✅ PN01146MM descargado.
# ✅ PN01147MM descargado.
# ✅ PN01148MM descargado.
# ✅ PN01149MM descargado.
# ✅ PN01150MM descargado.
# ✅ PN01151MM descargado.
# ✅ PN01152MM descargado.
# ✅ PN01153MM descargado.
# ✅ PN01154MM descargado.
# ✅ PN01155MM descargado.
# ✅ PN01156MM descargado.
# ✅ PN01157MM descargado.
# ✅ PN01158MM descargado.
# ✅ PN01159MM descargado.
# ✅ PN01160MM descargado.
# ✅ PN01161MM descargado.
# ✅ PN01162MM descargado.
# ✅ PN01163MM descargado.
# ✅ PN01164MM descargado.
# ✅ PN01165MM descargado.
# ✅ PN01166MM descargado.
# ✅ PN01167MM descargado.
# ✅ PN01168MM descargado.
# ✅ PN01169MM descargado.
# ✅ PN01170MM descargado.
# ✅ PN01171MM descargado.
# ✅ PN01172MM descargado.
# ✅ PN01173MM descargado.
# ✅ PN01174MM descargado.
# ✅ PN01175MM descargado.
# ✅ PN01176MM descargado.
# ✅ PN01177MM descargado.
# ⏱️ Batch done in 1.85s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 12 (1100 to 1199)
# ✅ PN01178MM descargado.
# ✅ PN01179MM descargado.
# ✅ PN01180MM descargado.
# ✅ PN01181MM descargado.
# ✅ PN01182MM descargado.
# ✅ PN01183MM descargado.
# ✅ PN01184MM descargado.
# ✅ PN01185MM descargado.
# ✅ PN01186MM descargado.
# ✅ PN01187MM descargado.
# ✅ PN01188MM descargado.
# ✅ PN01189MM descargado.
# ✅ PN01190MM descargado.
# ✅ PN01191MM descargado.
# ✅ PN01192MM descargado.
# ✅ PN01193MM descargado.
# ✅ PN01194MM descargado.
# ✅ PN01195MM descargado.
# ✅ PN01196MM descargado.
# ✅ PN01197MM descargado.
# ✅ PN01198MM descargado.
# ✅ PN01199MM descargado.
# ✅ PN01200MM descargado.
# ✅ PN01201MM descargado.
# ✅ PN01202MM descargado.
# ✅ PN01203MM descargado.
# ✅ PN01204MM descargado.
# ✅ PN01205PM descargado.
# ✅ PN01206PM descargado.
# ✅ PN01207PM descargado.
# ✅ PN01208PM descargado.
# ✅ PN01209PM descargado.
# ✅ PN01210PM descargado.
# ✅ PN01211PM descargado.
# ✅ PN01212PM descargado.
# ✅ PN01213PM descargado.
# ✅ PN01214PM descargado.
# ✅ PN01215PM descargado.
# ✅ PN01216PM descargado.
# ✅ PN01217PM descargado.
# ✅ PN01218PM descargado.
# ✅ PN01219PM descargado.
# ✅ PN01220PM descargado.
# ✅ PN01221PM descargado.
# ✅ PN01222PM descargado.
# ✅ PN01223XM descargado.
# ✅ PN01224XM descargado.
# ✅ PN01225XM descargado.
# ✅ PN01226XM descargado.
# ✅ PN01227XM descargado.
# ✅ PN01228XM descargado.
# ✅ PN01229XM descargado.
# ✅ PN01230XM descargado.
# ✅ PN01231XM descargado.
# ✅ PN01232XM descargado.
# ✅ PN01233XM descargado.
# ✅ PN01234PM descargado.
# ✅ PN01235PM descargado.
# ✅ PN01236PM descargado.
# ✅ PN01237PM descargado.
# ✅ PN01238PM descargado.
# ✅ PN01239PM descargado.
# ✅ PN01240PM descargado.
# ✅ PN01241PM descargado.
# ✅ PN01242PM descargado.
# ✅ PN01243PM descargado.
# ✅ PN01244PM descargado.
# ✅ PN01250PM descargado.
# ✅ PN01251PM descargado.
# ✅ PN01252PM descargado.
# ✅ PN01253PM descargado.
# ✅ PN01254PM descargado.
# ✅ PN01255PM descargado.
# ✅ PN01256PM descargado.
# ✅ PN01258PM descargado.
# ✅ PN01259PM descargado.
# ✅ PN01260PM descargado.
# ✅ PN01261PM descargado.
# ✅ PN01262PM descargado.
# ✅ PN01263PM descargado.
# ✅ PN01264PM descargado.
# ✅ PN01265PM descargado.
# ✅ PN01266PM descargado.
# ✅ PN01267PM descargado.
# ✅ PN01268PM descargado.
# ✅ PN01270PM descargado.
# ✅ PN01271PM descargado.
# ✅ PN01272PM descargado.
# ✅ PN01273PM descargado.
# ✅ PN01276PM descargado.
# ✅ PN01277PM descargado.
# ✅ PN01278PM descargado.
# ✅ PN01279PM descargado.
# ✅ PN01280PM descargado.
# ✅ PN01281PM descargado.
# ✅ PN01282PM descargado.
# ✅ PN01283PM descargado.
# ✅ PN01284PM descargado.
# ✅ PN01285PM descargado.
# ✅ PN01286PM descargado.
# ⏱️ Batch done in 1.89s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 13 (1200 to 1299)
# ✅ PN01287PM descargado.
# ✅ PN01288PM descargado.
# ✅ PN01289PM descargado.
# ✅ PN01290PM descargado.
# ✅ PN01291PM descargado.
# ✅ PN01292PM descargado.
# ✅ PN01293PM descargado.
# ✅ PN01296PM descargado.
# ✅ PN01297PM descargado.
# ✅ PN01298PM descargado.
# ✅ PN01299PM descargado.
# ✅ PN01300PM descargado.
# ✅ PN01301PM descargado.
# ✅ PN01302PM descargado.
# ✅ PN01303PM descargado.
# ✅ PN01304PM descargado.
# ✅ PN01305PM descargado.
# ✅ PN01306PM descargado.
# ✅ PN01308PM descargado.
# ✅ PN01309PM descargado.
# ✅ PN01310PM descargado.
# ✅ PN01311PM descargado.
# ✅ PN01313PM descargado.
# ✅ PN01314PM descargado.
# ✅ PN01315PM descargado.
# ✅ PN01336PM descargado.
# ❌ PN01337PM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01337PM/json/2000-1/2025-12/esp'
# ✅ PN01338PM descargado.
# ✅ PN01366PM descargado.
# ✅ PN01367PM descargado.
# ✅ PN01368PM descargado.
# ✅ PN01369PM descargado.
# ✅ PN01370PM descargado.
# ✅ PN01372PM descargado.
# ✅ PN01373PM descargado.
# ✅ PN01374PM descargado.
# ✅ PN01375PM descargado.
# ✅ PN01376PM descargado.
# ✅ PN01377PM descargado.
# ✅ PN01378PM descargado.
# ✅ PN01379PM descargado.
# ✅ PN01380PM descargado.
# ✅ PN01381PM descargado.
# ✅ PN01382PM descargado.
# ✅ PN01436PM descargado.
# ✅ PN01437PM descargado.
# ✅ PN01438PM descargado.
# ✅ PN01439PM descargado.
# ✅ PN01440PM descargado.
# ✅ PN01441PM descargado.
# ✅ PN01442PM descargado.
# ✅ PN01443PM descargado.
# ✅ PN01444PM descargado.
# ✅ PN01445PM descargado.
# ✅ PN01446PM descargado.
# ✅ PN01447PM descargado.
# ❌ PN01448BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01448BM/json/2000-1/2025-12/esp'
# ❌ PN01449BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01449BM/json/2000-1/2025-12/esp'
# ❌ PN01450BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01450BM/json/2000-1/2025-12/esp'
# ❌ PN01451BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01451BM/json/2000-1/2025-12/esp'
# ❌ PN01452BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01452BM/json/2000-1/2025-12/esp'
# ❌ PN01453BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01453BM/json/2000-1/2025-12/esp'
# ❌ PN01454BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01454BM/json/2000-1/2025-12/esp'
# ❌ PN01455BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01455BM/json/2000-1/2025-12/esp'
# ❌ PN01456BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01456BM/json/2000-1/2025-12/esp'
# ❌ PN01457BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01457BM/json/2000-1/2025-12/esp'
# ❌ PN01458BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01458BM/json/2000-1/2025-12/esp'
# ❌ PN01459BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01459BM/json/2000-1/2025-12/esp'
# ❌ PN01460BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01460BM/json/2000-1/2025-12/esp'
# ❌ PN01461BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01461BM/json/2000-1/2025-12/esp'
# ❌ PN01462BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01462BM/json/2000-1/2025-12/esp'
# ❌ PN01463BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01463BM/json/2000-1/2025-12/esp'
# ❌ PN01464BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01464BM/json/2000-1/2025-12/esp'
# ❌ PN01472BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01472BM/json/2000-1/2025-12/esp'
# ❌ PN01473BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01473BM/json/2000-1/2025-12/esp'
# ❌ PN01474BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01474BM/json/2000-1/2025-12/esp'
# ❌ PN01475BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01475BM/json/2000-1/2025-12/esp'
# ❌ PN01476BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01476BM/json/2000-1/2025-12/esp'
# ❌ PN01477BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01477BM/json/2000-1/2025-12/esp'
# ❌ PN01478BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01478BM/json/2000-1/2025-12/esp'
# ❌ PN01479BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01479BM/json/2000-1/2025-12/esp'
# ❌ PN01480BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01480BM/json/2000-1/2025-12/esp'
# ❌ PN01481BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01481BM/json/2000-1/2025-12/esp'
# ❌ PN01482BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01482BM/json/2000-1/2025-12/esp'
# ❌ PN01483BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01483BM/json/2000-1/2025-12/esp'
# ❌ PN01484BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01484BM/json/2000-1/2025-12/esp'
# ❌ PN01485BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01485BM/json/2000-1/2025-12/esp'
# ❌ PN01486BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01486BM/json/2000-1/2025-12/esp'
# ❌ PN01487BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01487BM/json/2000-1/2025-12/esp'
# ❌ PN01488BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01488BM/json/2000-1/2025-12/esp'
# ❌ PN01489BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01489BM/json/2000-1/2025-12/esp'
# ❌ PN01490BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01490BM/json/2000-1/2025-12/esp'
# ❌ PN01491BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01491BM/json/2000-1/2025-12/esp'
# ❌ PN01492BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01492BM/json/2000-1/2025-12/esp'
# ❌ PN01493BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01493BM/json/2000-1/2025-12/esp'
# ❌ PN01494BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01494BM/json/2000-1/2025-12/esp'
# ❌ PN01495BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01495BM/json/2000-1/2025-12/esp'
# ❌ PN01496BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01496BM/json/2000-1/2025-12/esp'
# ❌ PN01497BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01497BM/json/2000-1/2025-12/esp'
# ❌ PN01498BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01498BM/json/2000-1/2025-12/esp'
# ⏱️ Batch done in 1.04s — ✅ 55 | ⚪ 0 | ❌ 45
#
# 🔄 Processing batch 14 (1300 to 1399)
# ❌ PN01499BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01499BM/json/2000-1/2025-12/esp'
# ❌ PN01500BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01500BM/json/2000-1/2025-12/esp'
# ❌ PN01501BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01501BM/json/2000-1/2025-12/esp'
# ❌ PN01502BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01502BM/json/2000-1/2025-12/esp'
# ❌ PN01503BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01503BM/json/2000-1/2025-12/esp'
# ❌ PN01504BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01504BM/json/2000-1/2025-12/esp'
# ❌ PN01505BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01505BM/json/2000-1/2025-12/esp'
# ❌ PN01506BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01506BM/json/2000-1/2025-12/esp'
# ❌ PN01507BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01507BM/json/2000-1/2025-12/esp'
# ❌ PN01508BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01508BM/json/2000-1/2025-12/esp'
# ❌ PN01509BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01509BM/json/2000-1/2025-12/esp'
# ❌ PN01510BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01510BM/json/2000-1/2025-12/esp'
# ❌ PN01511BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01511BM/json/2000-1/2025-12/esp'
# ❌ PN01512BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01512BM/json/2000-1/2025-12/esp'
# ❌ PN01513BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01513BM/json/2000-1/2025-12/esp'
# ❌ PN01514BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01514BM/json/2000-1/2025-12/esp'
# ❌ PN01515BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01515BM/json/2000-1/2025-12/esp'
# ❌ PN01516BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01516BM/json/2000-1/2025-12/esp'
# ❌ PN01517BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01517BM/json/2000-1/2025-12/esp'
# ❌ PN01518BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01518BM/json/2000-1/2025-12/esp'
# ❌ PN01519BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01519BM/json/2000-1/2025-12/esp'
# ❌ PN01520BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01520BM/json/2000-1/2025-12/esp'
# ❌ PN01521BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01521BM/json/2000-1/2025-12/esp'
# ❌ PN01522BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01522BM/json/2000-1/2025-12/esp'
# ❌ PN01523BM falló: 200, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url='https://estadisticas.bcrp.gob.pe/estadisticas/series/api/PN01523BM/json/2000-1/2025-12/esp'
# ...
# ✅ RD40832BQ descargado.
# ✅ RD40833BQ descargado.
# ✅ RD40834BQ descargado.
# ✅ RD40835BQ descargado.
# ✅ RD40836BQ descargado.
# ✅ RD40837BQ descargado.
# ✅ RD40838BQ descargado.
# ✅ RD40839BQ descargado.
# ✅ RD40840BQ descargado.
# ✅ RD40841BQ descargado.
# ✅ RD40842BQ descargado.
# ✅ RD40843BQ descargado.
# ✅ RD40844BQ descargado.
# ✅ RD40845BQ descargado.
# ✅ RD40846BQ descargado.
# ✅ RD40847BQ descargado.
# ✅ RD40848BQ descargado.
# ✅ RD40849BQ descargado.
# ✅ RD40850BQ descargado.
# ✅ RD40851BQ descargado.
# ✅ RD40852BQ descargado.
# ✅ RD40853BQ descargado.
# ✅ RD40854BQ descargado.
# ✅ RD40855BQ descargado.
# ✅ RD40856BQ descargado.
# ✅ RD40857BQ descargado.
# ✅ RD40858BQ descargado.
# ✅ RD40859BQ descargado.
# ✅ RD40860BQ descargado.
# ✅ RD40861BQ descargado.
# ✅ RD40862BQ descargado.
# ✅ RD40863BQ descargado.
# ✅ RD40864BQ descargado.
# ✅ RD40865BQ descargado.
# ✅ RD40866BQ descargado.
# ✅ RD40867BQ descargado.
# ✅ RD40868BQ descargado.
# ✅ RD40869BQ descargado.
# ✅ RD40870BQ descargado.
# ✅ RD40871BQ descargado.
# ✅ RD40872BQ descargado.
# ✅ RD40873BQ descargado.
# ✅ RD40874BQ descargado.
# ✅ RD40875BQ descargado.
# ✅ RD40876BQ descargado.
# ✅ RD40877BQ descargado.
# ✅ RD40878BQ descargado.
# ✅ RD40879BQ descargado.
# ✅ RD40880BQ descargado.
# ✅ RD40881BQ descargado.
# ✅ RD40882BQ descargado.
# ✅ RD40883BQ descargado.
# ✅ RD40884BQ descargado.
# ✅ RD40885BQ descargado.
# ✅ RD40886BQ descargado.
# ✅ RD40887BQ descargado.
# ✅ RD40888BQ descargado.
# ✅ RD40889BQ descargado.
# ✅ RD40890BQ descargado.
# ✅ RD40891BQ descargado.
# ✅ RD40892BQ descargado.
# ✅ RD40893BQ descargado.
# ✅ RD40894BQ descargado.
# ✅ RD40895BQ descargado.
# ✅ RD40896BQ descargado.
# ✅ RD40897BQ descargado.
# ✅ RD40898BQ descargado.
# ✅ RD40899BQ descargado.
# ✅ RD40900BQ descargado.
# ✅ RD40901BQ descargado.
# ✅ RD40902BQ descargado.
# ✅ RD40903BQ descargado.
# ✅ RD40904BQ descargado.
# ✅ RD40905BQ descargado.
# ✅ RD40906BA descargado.
# ✅ RD40907BA descargado.
# ✅ RD40908BA descargado.
# ✅ RD40909BA descargado.
# ✅ RD40910BA descargado.
# ✅ RD40911BA descargado.
# ✅ RD40912BA descargado.
# ✅ RD40913BA descargado.
# ✅ RD40914BA descargado.
# ✅ RD40915BA descargado.
# ✅ RD40916BA descargado.
# ✅ RD40917BA descargado.
# ✅ RD40918BA descargado.
# ✅ RD40919BA descargado.
# ✅ RD40920BA descargado.
# ✅ RD40921BA descargado.
# ✅ RD40922BA descargado.
# ✅ RD40923BA descargado.
# ✅ RD40924BA descargado.
# ✅ RD40925BA descargado.
# ⏱️ Batch done in 1.75s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 160 (15900 to 15999)
# ✅ RD40926BA descargado.
# ✅ RD40927BA descargado.
# ✅ RD40928BA descargado.
# ✅ RD40929BA descargado.
# ✅ RD40930BA descargado.
# ✅ RD40931BA descargado.
# ✅ RD40932BA descargado.
# ✅ RD40933BA descargado.
# ✅ RD40934BA descargado.
# ✅ RD40935BA descargado.
# ✅ RD40936BA descargado.
# ✅ RD40937BA descargado.
# ✅ RD40938BA descargado.
# ✅ RD40939BA descargado.
# ✅ RD40940BA descargado.
# ✅ RD40941BA descargado.
# ✅ RD40942BA descargado.
# ✅ RD40943BA descargado.
# ✅ RD40944BA descargado.
# ✅ RD40945BA descargado.
# ✅ RD40946BA descargado.
# ✅ RD40947BA descargado.
# ✅ RD40948BA descargado.
# ✅ RD40949BA descargado.
# ✅ RD40950BA descargado.
# ✅ RD40951BA descargado.
# ✅ RD40952BA descargado.
# ✅ RD40953BA descargado.
# ✅ RD40954BA descargado.
# ✅ RD40955BA descargado.
# ✅ RD40956BA descargado.
# ✅ RD40957BA descargado.
# ✅ RD40958BA descargado.
# ✅ RD40959BA descargado.
# ✅ RD40960BA descargado.
# ✅ RD40961BA descargado.
# ✅ RD40962BA descargado.
# ✅ RD40963BA descargado.
# ✅ RD40964BA descargado.
# ✅ RD40965BA descargado.
# ✅ RD40966BA descargado.
# ✅ RD40967BA descargado.
# ✅ RD40968BA descargado.
# ✅ RD40969BA descargado.
# ✅ RD40970BA descargado.
# ✅ RD40971BA descargado.
# ✅ RD40972BA descargado.
# ✅ RD40973BA descargado.
# ✅ RD40974BA descargado.
# ✅ RD40975BA descargado.
# ✅ RD40976BA descargado.
# ✅ RD40977BA descargado.
# ✅ RD40978BA descargado.
# ✅ RD40979BA descargado.
# ✅ RD40980BA descargado.
# ✅ RD40981BA descargado.
# ✅ RD40982BA descargado.
# ✅ RD40983BA descargado.
# ✅ RD40984BA descargado.
# ✅ RD40985BA descargado.
# ✅ RD40986BA descargado.
# ✅ RD40987BA descargado.
# ✅ RD40988BA descargado.
# ✅ RD40989BA descargado.
# ✅ RD40990BA descargado.
# ✅ RD40991BA descargado.
# ✅ RD40992BA descargado.
# ✅ RD40993BA descargado.
# ✅ RD40994BA descargado.
# ✅ RD40995BA descargado.
# ✅ RD40996BA descargado.
# ✅ RD40997BA descargado.
# ✅ RD40998BA descargado.
# ✅ RD40999BA descargado.
# ✅ RD41000BA descargado.
# ✅ RD41001BA descargado.
# ✅ RD41002BA descargado.
# ✅ RD41003BA descargado.
# ✅ RD41004BA descargado.
# ✅ RD41005BA descargado.
# ✅ RD41006BA descargado.
# ✅ RD41007BA descargado.
# ✅ RD41008BA descargado.
# ✅ RD41009BA descargado.
# ✅ RD41010BA descargado.
# ✅ RD41011BA descargado.
# ✅ RD41012BA descargado.
# ✅ RD41013BA descargado.
# ✅ RD41014BA descargado.
# ✅ RD41015BA descargado.
# ✅ RD41016BA descargado.
# ✅ RD41017BA descargado.
# ✅ RD41018BA descargado.
# ✅ RD41019BA descargado.
# ✅ RD41020BA descargado.
# ✅ RD41021BA descargado.
# ✅ RD41022BA descargado.
# ✅ RD41023BA descargado.
# ✅ RD41024BA descargado.
# ✅ RD41025BA descargado.
# ⏱️ Batch done in 1.72s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 161 (16000 to 16099)
# ✅ RD41026BA descargado.
# ✅ RD41027BA descargado.
# ✅ RD41028BA descargado.
# ✅ RD41029BA descargado.
# ✅ RD41030BA descargado.
# ✅ RD41031BA descargado.
# ✅ RD41032BA descargado.
# ✅ RD41033BA descargado.
# ✅ RD41034BA descargado.
# ✅ RD41035BA descargado.
# ✅ RD41036BA descargado.
# ✅ RD41037BA descargado.
# ✅ RD41038BA descargado.
# ✅ RD41039BA descargado.
# ✅ RD41040BA descargado.
# ✅ RD41041BA descargado.
# ✅ RD41042BA descargado.
# ✅ RD41043BA descargado.
# ✅ RD41044BA descargado.
# ✅ RD41045BA descargado.
# ✅ RD41046BA descargado.
# ✅ RD41047BA descargado.
# ✅ RD41048BA descargado.
# ✅ RD41049BA descargado.
# ✅ RD41050BA descargado.
# ✅ RD41051BA descargado.
# ✅ RD41052BA descargado.
# ✅ RD41053BA descargado.
# ✅ RD41054BA descargado.
# ✅ RD41055BA descargado.
# ✅ RD41056BA descargado.
# ✅ RD41057BA descargado.
# ✅ RD41058BA descargado.
# ✅ RD41059BA descargado.
# ✅ RD41060BA descargado.
# ✅ RD41061BA descargado.
# ✅ RD41062BA descargado.
# ✅ RD41063BA descargado.
# ✅ RD41064BA descargado.
# ✅ RD41065BA descargado.
# ✅ RD41066BA descargado.
# ✅ RD41067BA descargado.
# ✅ RD41068BA descargado.
# ✅ RD41069BA descargado.
# ✅ RD41070BA descargado.
# ✅ RD41071BA descargado.
# ✅ RD41072BA descargado.
# ✅ RD41073BA descargado.
# ✅ RD41074BA descargado.
# ✅ RD41075BA descargado.
# ✅ RD41076BA descargado.
# ✅ RD41077BA descargado.
# ✅ RD41078BA descargado.
# ✅ RD41079BA descargado.
# ✅ RD41080BA descargado.
# ✅ RD41081BA descargado.
# ✅ RD41082BA descargado.
# ✅ RD41083BA descargado.
# ✅ RD41084BA descargado.
# ✅ RD41085BA descargado.
# ✅ RD41086BA descargado.
# ✅ RD41087BA descargado.
# ✅ RD41088BA descargado.
# ✅ RD41089BA descargado.
# ✅ RD41090BA descargado.
# ✅ RD41091BA descargado.
# ✅ RD41092BA descargado.
# ✅ RD41093BA descargado.
# ✅ RD41094BA descargado.
# ✅ RD41095BA descargado.
# ✅ RD41096BA descargado.
# ✅ RD41097BA descargado.
# ✅ RD41098BA descargado.
# ✅ RD41099BA descargado.
# ✅ RD41100BA descargado.
# ✅ RD41101BA descargado.
# ✅ RD41102BA descargado.
# ✅ RD41103BA descargado.
# ✅ RD41104BA descargado.
# ✅ RD41105BA descargado.
# ✅ RD41106BA descargado.
# ✅ RD41107BA descargado.
# ✅ RD41108BA descargado.
# ✅ RD41109BA descargado.
# ✅ RD41110BA descargado.
# ✅ RD41111BA descargado.
# ✅ RD41112BA descargado.
# ✅ RD41113BA descargado.
# ✅ RD41114BA descargado.
# ✅ RD41115BA descargado.
# ✅ RD41116BA descargado.
# ✅ RD41117BA descargado.
# ✅ RD41118BA descargado.
# ✅ RD41119BA descargado.
# ✅ RD41120BA descargado.
# ✅ RD41121BA descargado.
# ✅ RD41122BA descargado.
# ✅ RD41123BA descargado.
# ✅ RD41124BA descargado.
# ✅ RD41125BA descargado.
# ⏱️ Batch done in 1.75s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 162 (16100 to 16199)
# ✅ RD41126BA descargado.
# ✅ RD41127BA descargado.
# ✅ RD41128BA descargado.
# ✅ RD41129BA descargado.
# ✅ RD41130BA descargado.
# ✅ RD41131BA descargado.
# ✅ RD41132BA descargado.
# ✅ RD41133BA descargado.
# ✅ RD41134BA descargado.
# ✅ RD41135BA descargado.
# ✅ RD41136BA descargado.
# ✅ RD41137BA descargado.
# ✅ RD41138BA descargado.
# ✅ RD41139BA descargado.
# ✅ RD41140BA descargado.
# ✅ RD41141BA descargado.
# ✅ RD41142BA descargado.
# ✅ RD41143BA descargado.
# ✅ RD41144BA descargado.
# ✅ RD41145BA descargado.
# ✅ RD41146BA descargado.
# ✅ RD41147BA descargado.
# ✅ RD41148BA descargado.
# ✅ RD41149BA descargado.
# ✅ RD41150BA descargado.
# ✅ RD41151BA descargado.
# ✅ RD41152BA descargado.
# ✅ RD41153BA descargado.
# ✅ RD41154BA descargado.
# ✅ RD41155BA descargado.
# ✅ RD41156BA descargado.
# ✅ RD41157BA descargado.
# ✅ RD41158BA descargado.
# ✅ RD41159BA descargado.
# ✅ RD41160BA descargado.
# ✅ RD41161BA descargado.
# ✅ RD41162BA descargado.
# ✅ RD41163BA descargado.
# ✅ RD41164BA descargado.
# ✅ RD41165BA descargado.
# ✅ RD41166BA descargado.
# ✅ RD41167BA descargado.
# ✅ RD41168BA descargado.
# ✅ RD41169BA descargado.
# ✅ RD41170BA descargado.
# ✅ RD41171BA descargado.
# ✅ RD41172BA descargado.
# ✅ RD41173BA descargado.
# ✅ RD41174BA descargado.
# ✅ RD41175BA descargado.
# ✅ RD41176BA descargado.
# ✅ RD41177BA descargado.
# ✅ RD41178BA descargado.
# ✅ RD41179BA descargado.
# ✅ RD41180BA descargado.
# ✅ RD41181BA descargado.
# ✅ RD41182BA descargado.
# ✅ RD41183BA descargado.
# ✅ RD41184BA descargado.
# ✅ RD41185BA descargado.
# ✅ RD41186BA descargado.
# ✅ RD41187BA descargado.
# ✅ RD41188BA descargado.
# ✅ RD41189BA descargado.
# ✅ RD41190BA descargado.
# ✅ RD41191BA descargado.
# ✅ RD41192BA descargado.
# ✅ RD41193BA descargado.
# ✅ RD41194BA descargado.
# ✅ RD41195BA descargado.
# ✅ RD41196BA descargado.
# ✅ RD41197BA descargado.
# ✅ RD41198BA descargado.
# ✅ RD41199BA descargado.
# ✅ RD41200BA descargado.
# ✅ RD41201BA descargado.
# ✅ RD41202BA descargado.
# ✅ RD41203BA descargado.
# ✅ RD41204BA descargado.
# ✅ RD41205BA descargado.
# ✅ RD41206BA descargado.
# ✅ RD41207BA descargado.
# ✅ RD41208BA descargado.
# ✅ RD41209BA descargado.
# ✅ RD41210BA descargado.
# ✅ RD41211BA descargado.
# ✅ RD41212BA descargado.
# ✅ RD41213BA descargado.
# ✅ RD41214BA descargado.
# ✅ RD41215BA descargado.
# ✅ RD41216BA descargado.
# ✅ RD41217BA descargado.
# ✅ RD41218BA descargado.
# ✅ RD41219BA descargado.
# ✅ RD41220BA descargado.
# ✅ RD41221BA descargado.
# ✅ RD41222BA descargado.
# ✅ RD41223BA descargado.
# ✅ RD41224BA descargado.
# ✅ RD41225BA descargado.
# ⏱️ Batch done in 1.7s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 163 (16200 to 16299)
# ✅ RD41226BA descargado.
# ✅ RD41227BA descargado.
# ✅ RD41228BA descargado.
# ✅ RD41229BA descargado.
# ✅ RD41230BA descargado.
# ✅ RD41231BA descargado.
# ✅ RD41232BA descargado.
# ✅ RD41233BA descargado.
# ✅ RD41234BA descargado.
# ✅ RD41235BA descargado.
# ✅ RD41236BA descargado.
# ✅ RD41237BA descargado.
# ✅ RD41238BA descargado.
# ✅ RD41239BA descargado.
# ✅ RD41240BA descargado.
# ✅ RD41241BA descargado.
# ✅ RD41242BA descargado.
# ✅ RD41243BA descargado.
# ✅ RD41244BA descargado.
# ✅ RD41245BA descargado.
# ✅ RD41246BA descargado.
# ✅ RD41247BA descargado.
# ✅ RD41248BA descargado.
# ✅ RD41249BA descargado.
# ✅ RD41250BA descargado.
# ✅ RD41251BA descargado.
# ✅ RD41252BA descargado.
# ✅ RD41253BA descargado.
# ✅ RD41254BA descargado.
# ✅ RD41255BA descargado.
# ✅ RD41256BA descargado.
# ✅ RD41257BA descargado.
# ✅ RD41258BA descargado.
# ✅ RD41259BA descargado.
# ✅ RD41260BA descargado.
# ✅ RD41261BA descargado.
# ✅ RD41262BA descargado.
# ✅ RD41263BA descargado.
# ✅ RD41264BA descargado.
# ✅ RD41265BA descargado.
# ✅ RD41266BA descargado.
# ✅ RD41267BA descargado.
# ✅ RD41268BA descargado.
# ✅ RD41269BA descargado.
# ✅ RD41270BA descargado.
# ✅ RD41271BA descargado.
# ✅ RD41272BA descargado.
# ✅ RD41273BA descargado.
# ✅ RD41274BA descargado.
# ✅ RD41275BA descargado.
# ✅ RD41276BA descargado.
# ✅ RD41277BA descargado.
# ✅ RD41278BA descargado.
# ✅ RD41279BA descargado.
# ✅ RD41280BA descargado.
# ✅ RD41281BA descargado.
# ✅ RD41282BA descargado.
# ✅ RD41283BA descargado.
# ✅ RD41284BA descargado.
# ✅ RD41285BA descargado.
# ✅ RD41286BA descargado.
# ✅ RD41287BA descargado.
# ✅ RD41288BA descargado.
# ✅ RD41289BA descargado.
# ✅ RD41290BA descargado.
# ✅ RD41291BA descargado.
# ✅ RD41292BA descargado.
# ✅ RD41293BA descargado.
# ✅ RD41294BA descargado.
# ✅ RD41295BA descargado.
# ✅ RD41296BA descargado.
# ✅ RD41297BA descargado.
# ✅ RD41298BA descargado.
# ✅ RD41299BA descargado.
# ✅ RD41300BA descargado.
# ✅ RD41301BA descargado.
# ✅ RD41302BA descargado.
# ✅ RD41303BA descargado.
# ✅ RD41304BA descargado.
# ✅ RD41305BA descargado.
# ✅ RD41306BA descargado.
# ✅ RD41307BA descargado.
# ✅ RD41308BA descargado.
# ✅ RD41309BA descargado.
# ✅ RD41310BA descargado.
# ✅ RD41311BA descargado.
# ✅ RD41312BA descargado.
# ✅ RD41313BA descargado.
# ✅ RD41314BA descargado.
# ✅ RD41315BA descargado.
# ✅ RD41316BA descargado.
# ✅ RD41317BA descargado.
# ✅ RD41318BA descargado.
# ✅ RD41319BA descargado.
# ✅ RD41320BA descargado.
# ✅ RD41321BA descargado.
# ✅ RD41322BA descargado.
# ✅ RD41323BA descargado.
# ✅ RD41324BA descargado.
# ✅ RD41325BA descargado.
# ⏱️ Batch done in 1.78s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 164 (16300 to 16399)
# ✅ RD41326BA descargado.
# ✅ RD41327BA descargado.
# ✅ RD41328BA descargado.
# ✅ RD41329BA descargado.
# ✅ RD41330BA descargado.
# ✅ RD41331BA descargado.
# ✅ RD41332BA descargado.
# ✅ RD41333BA descargado.
# ✅ RD41334BA descargado.
# ✅ RD41335BA descargado.
# ✅ RD41336BA descargado.
# ✅ RD41337BA descargado.
# ✅ RD41338BA descargado.
# ✅ RD41339BA descargado.
# ✅ RD41340BA descargado.
# ✅ RD41341BA descargado.
# ✅ RD41342BA descargado.
# ✅ RD41343BA descargado.
# ✅ RD41344BA descargado.
# ✅ RD41345BA descargado.
# ✅ RD41346BA descargado.
# ✅ RD41347BA descargado.
# ✅ RD41348BA descargado.
# ✅ RD41349BA descargado.
# ✅ RD41350BA descargado.
# ✅ RD41351BA descargado.
# ✅ RD41352BA descargado.
# ✅ RD41353BA descargado.
# ✅ RD41354BA descargado.
# ✅ RD41355BA descargado.
# ✅ RD41356BA descargado.
# ✅ RD41357BA descargado.
# ✅ RD41358BA descargado.
# ✅ RD41359BA descargado.
# ✅ RD41360BA descargado.
# ✅ RD41361BA descargado.
# ✅ RD41362BA descargado.
# ✅ RD41363BA descargado.
# ✅ RD41364BA descargado.
# ✅ RD41365BA descargado.
# ✅ RD41366BA descargado.
# ✅ RD41367BA descargado.
# ✅ RD41368BA descargado.
# ✅ RD41369BA descargado.
# ✅ RD41370BA descargado.
# ✅ RD41371BA descargado.
# ✅ RD41372BA descargado.
# ✅ RD41373BA descargado.
# ✅ RD41374BA descargado.
# ✅ RD41375BA descargado.
# ✅ RD41376BA descargado.
# ✅ RD41377BA descargado.
# ✅ RD41378BA descargado.
# ✅ RD41379BA descargado.
# ✅ RD41380BA descargado.
# ✅ RD41381BA descargado.
# ✅ RD41382BA descargado.
# ✅ RD41383BA descargado.
# ✅ RD41384BA descargado.
# ✅ RD41385BA descargado.
# ✅ RD41386BA descargado.
# ✅ RD41387BA descargado.
# ✅ RD41388BA descargado.
# ✅ RD41389BA descargado.
# ✅ RD41390BA descargado.
# ✅ RD41391BA descargado.
# ✅ RD41392BA descargado.
# ✅ RD41393BA descargado.
# ✅ RD41394BA descargado.
# ✅ RD41395BA descargado.
# ✅ RD41396BA descargado.
# ✅ RD41397BA descargado.
# ✅ RD41398BA descargado.
# ✅ RD41399BA descargado.
# ✅ PD41400AM descargado.
# ✅ PD41401AM descargado.
# ✅ PD41402AM descargado.
# ✅ PD41403AM descargado.
# ✅ PD41404AM descargado.
# ✅ PD41405AM descargado.
# ✅ PD41406AM descargado.
# ✅ PD41407AM descargado.
# ✅ PD41408AM descargado.
# ✅ PD41409AM descargado.
# ✅ PD41410AM descargado.
# ✅ PD41411AM descargado.
# ✅ PD41412AM descargado.
# ✅ PD41413AM descargado.
# ✅ PD41414AM descargado.
# ✅ PD41415AM descargado.
# ✅ PD41416AM descargado.
# ✅ PD41417AM descargado.
# ✅ PD41418AM descargado.
# ✅ PD41419AM descargado.
# ✅ PD41420AM descargado.
# ✅ PD41421AM descargado.
# ✅ PD41422AM descargado.
# ✅ PD41423AM descargado.
# ✅ PD41424AM descargado.
# ✅ PD41425AM descargado.
# ⏱️ Batch done in 1.82s — ✅ 100 | ⚪ 0 | ❌ 0
#
# 🔄 Processing batch 165 (16400 to 16417)
# ✅ PD41426AM descargado.
# ✅ PD41427AM descargado.
# ✅ PD41428AM descargado.
# ✅ PD41429AM descargado.
# ✅ PD41430AM descargado.
# ✅ PD41431AM descargado.
# ✅ PD41432AM descargado.
# ✅ PD41433AM descargado.
# ✅ PD41434AM descargado.
# ✅ PD41435AM descargado.
# ✅ PD41436AM descargado.
# ✅ PD41437AM descargado.
# ✅ PD41438AM descargado.
# ✅ PD41439AM descargado.
# ✅ PD41440MM descargado.
# ✅ PD41441MM descargado.
# ✅ PD41442MM descargado.
# ✅ PD41443MM descargado.
# ⏱️ Batch done in 0.53s — ✅ 18 | ⚪ 0 | ❌ 0
# /tmp/ipykernel_40799/2377385193.py:48: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2025-06-13T23:11:01.059037' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_control.loc[df_control["codigo_serie"] == codigo, "ultima_actualizacion"] = timestamp
# /tmp/ipykernel_40799/2377385193.py:49: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_control.loc[df_control["codigo_serie"] == codigo, "observaciones"] = obs
# ✅ Control panel updated with 16418 results.

# %%
# Read all 16k Parquet files and write into one
duckdb.sql("""
    COPY (
        SELECT * FROM read_parquet('../data/bronze/*.parquet')
    ) TO '../data/silver/series_all.parquet' (FORMAT PARQUET);
""")
